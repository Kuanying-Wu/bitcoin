# %%
import sys
import os
import pandas as pd
import matplotlib.pyplot as plt
import importlib as ib
from module import main
from module import plot

def reload_module(mode_name):
    ib.reload(mode_name)

# %%
ib.reload(main)
ib.reload(plot)
# Out:
# <module 'module.plot' from 'C:\\Users\\user\\Desktop\\coin-record\\module\\plot.py'>

# %% [markdown]
# # BITCOIN

# %%
df=main.read_excel()
df_ana=df.copy()
df_buy=df_ana.query('is_sell == 0')
df_sell=df_ana.query('is_sell == 1')

buy_price, buy_coin, coin_type = main.calculate_cost(df_buy)
sell_price, sell_coin, coin_type = main.calculate_cost(df_sell)
# sell_price, sell_coin=0, 0
main.trade_image(buy_price, buy_coin, sell_price, sell_coin, coin_type)
# Out:
#                     Value
# 最低買點(USDT)   60570.268015
# 目前利潤(USDT)     -66.082162
# 剩餘coin(BTC)      0.001091

# %%
plot.Manager('BTC').main()
# Out:
#                     Value
# 最低買點(USDT)   60570.268015
# 目前利潤(USDT)     -66.082162
# 剩餘coin(BTC)      0.001091
# (3, 6)

# %%
ib.reload(ok)
# Out:
# <module 'module.ok' from 'C:\\Users\\user\\Desktop\\coin-record\\module\\ok.py'>

# %%
def read_excel(file_path='record.xlsx', sheet_name='main'):
    df = pd.read_excel(file_path, sheet_name=sheet_name)
    df = df[df['coin_type'] == 'BTC']
    return df
read_excel(file_path='record.xlsx', sheet_name='main')
# Out:
#   coin_type  average_price(USDT)  num_order(coin)  num_deal(USDT)
# 0       BTC             60617.46         0.000840       50.918666  \
# 1       BTC             60612.05         0.000417       25.275225
# 2       BTC             60000.00         0.000100       77.000000
# 3       BTC             60000.00         0.000100       77.000000
#
#    num_deal_fixed(USDT)  is_sell
# 0             50.944126        0
# 1             25.287862        0
# 2             76.961500        1
# 3             77.038500        0
